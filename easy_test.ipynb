# %%
import pickle
import pandas as pd
import re
import os
import logging
from exhibitHistory import run
from datetime import datetime
import matplotlib.pyplot as plt
from prophet import Prophet
from scipy.optimize import linear_sum_assignment
from prophet.diagnostics import performance_metrics
from prophet.diagnostics import cross_validation

logging.basicConfig(level=logging.DEBUG,
                    format="%(asctime)s %(levelname)s %(message)s")

if os.path.exists("artists.pkl"):
    with open("artists.pkl", "rb") as file:
        artists = pickle.load(file)

else:
    artists = run()
    with open('artists.pkl', 'wb') as file:
        pickle.dump(artists, file)



putondisp = []
puton2023 = []
bestPerPerson = pd.DataFrame(columns=["Date", "Predicted_Views", "Artist"])


fullWiki = pd.read_csv("artistData.csv")

def interest(name: str) -> list:
    artistdf = fullWiki[fullWiki['title'] == name]
    print(artistdf.groupby("title", as_index=False)['views'].mean())
    print(artistdf.groupby("title", as_index=False)['views'].max())
    print(artistdf.groupby("title", as_index=False)['views'].std())



def getArt(findName: str) -> list:
    poi = next((x for x in artists if x.name == findName), None)
    for art in poi.names:
        date_pattern = re.compile(r'\([^)]+\)\s*\(([^)]+)\)')
        #print(art.exData)
        for key, val in art.exData.items():
            if len(val) != 0 and key != "legacy":
               #print(key, val)
               #print(exhibit["title"], exhibit["opening_date"])


               for k, v in val[0].items():
                   if k == "description" :
                        dateMatch =  date_pattern.search(v)
                        dateRange = dateMatch.group(1) if dateMatch else None
                        print(dateRange, past2019(dateRange))
                        if past2019(dateRange):
                            putondisp.append([findName, turnDates(dateRange)])
                        if past2023(dateRange):
                            puton2023.append([findName, turnDates(dateRange)])





def past2019(date_range) -> bool:
    if date_range is None:
        return False

    try:
        start, end = date_range.split('-')
        #print(start, end)
        if len(start.split())  != len(end.split()):
            _, end_year = end.split(",")
            start = start + "," + end_year
        #print(start, end)

        start = datetime.strptime(start, '%B %d, %Y')
        end = datetime. strptime(end, '%B %d, %Y')

        ref = datetime(2019, 1, 1)
        return start > ref or end > ref
    except:
        print("failed date_range: ", date_range)
        return False

def past2023(date_range) -> bool:
  if date_range is None:
        return False
  try:
        start, end = date_range.split('-')
        #print(start, end)
        if len(start.split())  != len(end.split()):
            _, end_year = end.split(",")
            start = start + "," + end_year
        #print(start, end)

        start = datetime.strptime(start, '%B %d, %Y')
        end = datetime. strptime(end, '%B %d, %Y')

        ref = datetime(2023, 1, 1)
        return start > ref or end > ref
  except:
        print("failed date_range: ", date_range)
        return False

def turnDates(date_range) -> list:
    start, end = date_range.split('-')
    #print(start, end)
    if len(start.split())  != len(end.split()):
        _, end_year = end.split(",")
        start = start + "," + end_year
    #print(start, end)

    start = datetime.strptime(start, '%B %d, %Y')
    end = datetime. strptime(end, '%B %d, %Y')

    return [start, end]




for i in range(50):
    name = artists[i].name
    getArt(name)
print(putondisp)

def graphPerson(name: str) -> None:
    artResponse = pd.DataFrame(putondisp, columns=['artist', 'display_period'])
    merged = pd.merge(fullWiki, artResponse, left_on='title', right_on='artist')

    merged['timestamp'] = pd.to_datetime(merged['timestamp'])

    workingDF = merged[merged["title"] == name]

    plt.figure(figsize=(10, 6))
    plt.scatter(workingDF['timestamp'], workingDF['views'], label='Wikipedia Views')
    plt.title(name + " Wikipedia Views Over Time")
    plt.xlabel('Date')
    plt.ylabel('Views')
    plt.legend()

    display_start, display_end = workingDF['display_period'].iloc[0]
    plt.axvspan(display_start, display_end, color='yellow', alpha=0.3, label='Art on Display')
    plt.legend()

    plt.show()


def prophetPerson(name: str) -> list:
    artResponse = pd.DataFrame(putondisp, columns=['artist', 'display_period'])
    merged = pd.merge(fullWiki, artResponse, left_on='title', right_on='artist')

    merged['timestamp'] = pd.to_datetime(merged['timestamp'])
    workingDF = merged[merged["title"] == name]

    prophetData = workingDF[['timestamp', 'views']].rename(columns={'timestamp': 'ds', 'views': 'y'})
    model = Prophet()
    model.fit(prophetData)

    future = model.make_future_dataframe(periods=365)

    forecast = model.predict(future)

    fForecast = forecast[forecast['ds'] > max(workingDF['timestamp'])]

    best_time_to_display = fForecast.nlargest(3, 'yhat')[['ds', 'yhat']]
    best_time_to_display["Artist"] = name
    best_time_to_display.columns = ['Date', 'Predicted_Views', "Artist"]


    #df_cv = cross_validation(model, initial='100 days', period='180 days', horizon = '365 days')
    #cutoffs = pd.to_datetime(['2021-02-15'])
    #df_cv2 = cross_validation(model, cutoffs=cutoffs, horizon='365 days')
    #df_p = performance_metrics(df_cv)
    #print(df_p.head())




    fig, ax = plt.subplots(figsize=(10, 6))
    model.plot(forecast, ax=ax)
    plt.title(name + " Wikipedia Views Forecast")
    plt.xlabel('Date')
    plt.ylabel('Views')

    for index, row in best_time_to_display.iterrows():
       plt.axvline(row['Date'], color='red', linestyle='--', label='Best Time to Display')
    plt.legend()
    plt.show()


    return best_time_to_display


for i in range(4):
    name = putondisp[i][0]
    #graphPerson(name)
    print("on prophet ", i, len(putondisp))
    logging.info(f'Processing art {i} of {len(putondisp)}')

    bestPerPerson = bestPerPerson.append(prophetPerson(name), ignore_index =True)











bestPerPerson.to_csv('grouped_data.csv', index=False)
with open('puton2023.pkl', 'wb') as file:
        pickle.dump(puton2023, file)
# Out:
# June 26-October 4, 1936 False
# May 5-September 22, 2019 True
# April 25-June 3, 1934 False
# April 25-June 3, 1928 False
# February 6-April 15, 1990 False
# None False
# April 24-June 2, 1935 False
# May 4-June 7, 1926 False
# May 3-June 29, 1919 False
# May 6-June 14, 1936 False
# May 6-June 14, 1936 False
# February 20-March 13, 1935 False
# May 3-June 11, 1939 False
# May 4-June 7, 1925 False
# February 7-March 27, 1968 False
# None False
# May 24-July 27, 2013 False
# May 2-June 11, 1933 False
# April 13-June 9, 1946 False
# February 9-March 20, 1938 False
# February 9-March 20, 1938 False
# May 19-July 21, 1996 False
# April 13-June 9, 1946 False
# May 24-July 27, 2013 False
# February 7-March 27, 1968 False
# February 7-March 27, 1968 False
# June 17-August 24, 1942 False
# February 9-March 20, 1938 False
# failed date_range:  co-organizer
# co-organizer False
# failed date_range:  co-organizer
# failed date_range:  co-organizer
# April 30-June 8, 1947 False
# February 9-March 20, 1938 False
# February 9-March 20, 1938 False
# February 7-March 27, 1968 False
# February 7-March 27, 1968 False
# February 9-March 20, 1938 False
# failed date_range:  October 6-31, 1937
# October 6-31, 1937 False
# failed date_range:  October 6-31, 1937
# failed date_range:  October 6-31, 1937
# June 2-August 2, 1987 False
# November 15-December 11, 1938 False
# June 2-August 2, 1987 False
# July 2-October 29, 2023 True
# None False
# failed date_range:  December 4-29, 1935
# December 4-29, 1935 False
# failed date_range:  December 4-29, 1935
# failed date_range:  December 4-29, 1935
# None False
# None False
# None False
# None False
# None False
# June 23-September 28, 1941 False
# June 23-September 28, 1941 False
# June 23-September 28, 1941 False
# June 26-October 4, 1936 False
# None False
# March 3, 1958-October 11, 1959 False
# December 7, 1932-January 8, 1933 False
# December 7, 1932-January 8, 1933 False
# December 7, 1932-January 8, 1933 False
# December 7, 1932-January 8, 1933 False
# December 7, 1932-January 8, 1933 False
# May 28-December 9, 1937 False
# October 1, 1944-January 31, 1945 False
# February 27-April 21, 1985 False
# February 27-April 21, 1985 False
# June 23-September 28, 1941 False
# [['Henry Keller', [datetime.datetime(2019, 5, 5, 0, 0), datetime.datetime(2019, 9, 22, 0, 0)]], ['Otto H. Bacher', [datetime.datetime(2022, 5, 30, 0, 0), datetime.datetime(2022, 9, 5, 0, 0)]], ['Eugène Delacroix', [datetime.datetime(2022, 9, 11, 0, 0), datetime.datetime(2023, 1, 8, 0, 0)]], ['Paul Cadmus', [datetime.datetime(2019, 10, 13, 0, 0), datetime.datetime(2020, 2, 23, 0, 0)]], ['Paul Cadmus', [datetime.datetime(2019, 10, 13, 0, 0), datetime.datetime(2020, 2, 23, 0, 0)]], ['Paul Cadmus', [datetime.datetime(2019, 10, 13, 0, 0), datetime.datetime(2020, 2, 23, 0, 0)]], ['Mabel Dwight', [datetime.datetime(2021, 7, 18, 0, 0), datetime.datetime(2021, 12, 26, 0, 0)]], ['Oqwa Pi', [datetime.datetime(2023, 12, 8, 0, 0), datetime.datetime(2024, 12, 8, 0, 0)]], ['John Marin', [datetime.datetime(2022, 9, 11, 0, 0), datetime.datetime(2023, 1, 8, 0, 0)]], ['John Marin', [datetime.datetime(2022, 9, 11, 0, 0), datetime.datetime(2023, 1, 8, 0, 0)]], ['John Marin', [datetime.datetime(2022, 9, 11, 0, 0), datetime.datetime(2023, 1, 8, 0, 0)]], ['John Marin', [datetime.datetime(2022, 9, 11, 0, 0), datetime.datetime(2023, 1, 8, 0, 0)]], ['John Marin', [datetime.datetime(2022, 9, 11, 0, 0), datetime.datetime(2023, 1, 8, 0, 0)]], ['John Marin', [datetime.datetime(2022, 9, 11, 0, 0), datetime.datetime(2023, 1, 8, 0, 0)]], ['John Marin', [datetime.datetime(2022, 9, 11, 0, 0), datetime.datetime(2023, 1, 8, 0, 0)]], ['Kenneth Hayes Miller', [datetime.datetime(2021, 7, 18, 0, 0), datetime.datetime(2021, 12, 26, 0, 0)]], ['Benton Spruance', [datetime.datetime(2021, 7, 18, 0, 0), datetime.datetime(2021, 12, 26, 0, 0)]], ['Benton Spruance', [datetime.datetime(2021, 7, 18, 0, 0), datetime.datetime(2021, 12, 26, 0, 0)]], ['Benton Spruance', [datetime.datetime(2021, 7, 18, 0, 0), datetime.datetime(2021, 12, 26, 0, 0)]], ['Benton Spruance', [datetime.datetime(2021, 7, 18, 0, 0), datetime.datetime(2021, 12, 26, 0, 0)]], ['Benton Spruance', [datetime.datetime(2021, 7, 18, 0, 0), datetime.datetime(2021, 12, 26, 0, 0)]], ['James McNeill Whistler', [datetime.datetime(2023, 10, 8, 0, 0), datetime.datetime(2024, 1, 14, 0, 0)]], ['Albrecht Dürer', [datetime.datetime(2019, 5, 5, 0, 0), datetime.datetime(2019, 9, 22, 0, 0)]], ['Albrecht Dürer', [datetime.datetime(2019, 5, 5, 0, 0), datetime.datetime(2019, 9, 22, 0, 0)]], ['Hanns Lautensack', [datetime.datetime(2023, 7, 2, 0, 0), datetime.datetime(2023, 10, 29, 0, 0)]]]
# on prophet  0 25
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/r084wxp4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/er33hej9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43317', 'data', 'file=/tmp/tmped772b7c/r084wxp4.json', 'init=/tmp/tmped772b7c/er33hej9.json', 'output', 'file=/tmp/tmped772b7c/prophet_modell9gg1cmb/prophet_model-20231220141321.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:13:21 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:13:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-17-5176c21c74c4>:204: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bestPerPerson = bestPerPerson.append(prophetPerson(name), ignore_index =True)
# on prophet  1 25
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/ci86alyk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/wp7i1rfc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28511', 'data', 'file=/tmp/tmped772b7c/ci86alyk.json', 'init=/tmp/tmped772b7c/wp7i1rfc.json', 'output', 'file=/tmp/tmped772b7c/prophet_modelscjrwqhi/prophet_model-20231220141323.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:13:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:13:23 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-17-5176c21c74c4>:204: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bestPerPerson = bestPerPerson.append(prophetPerson(name), ignore_index =True)
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/knlq8o_n.json
# on prophet  2 25
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/4qwq9syg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28900', 'data', 'file=/tmp/tmped772b7c/knlq8o_n.json', 'init=/tmp/tmped772b7c/4qwq9syg.json', 'output', 'file=/tmp/tmped772b7c/prophet_modelf_ie_5ma/prophet_model-20231220141324.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:13:24 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:13:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-17-5176c21c74c4>:204: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bestPerPerson = bestPerPerson.append(prophetPerson(name), ignore_index =True)
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/d_r6rjvr.json
# on prophet  3 25
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/5leo8gy3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87422', 'data', 'file=/tmp/tmped772b7c/d_r6rjvr.json', 'init=/tmp/tmped772b7c/5leo8gy3.json', 'output', 'file=/tmp/tmped772b7c/prophet_model8c0l41da/prophet_model-20231220141326.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:13:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:13:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-17-5176c21c74c4>:204: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bestPerPerson = bestPerPerson.append(prophetPerson(name), ignore_index =True)
# on prophet  4 25
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/4i5c6bq2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmped772b7c/p6_ngu77.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41255', 'data', 'file=/tmp/tmped772b7c/4i5c6bq2.json', 'init=/tmp/tmped772b7c/p6_ngu77.json', 'output', 'file=/tmp/tmped772b7c/prophet_modelq8_o_xl9/prophet_model-20231220141329.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 14:13:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 14:13:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# <ipython-input-17-5176c21c74c4>:204: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bestPerPerson = bestPerPerson.append(prophetPerson(name), ignore_index =True)
